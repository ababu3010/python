# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = 10
b = "5"
print(a + int(b))
# Out:
# 15

# %%
def add_numbers(a, b):
    return a + b

# %%
numbers = [1, 2, 3, 4]
###print(numbers[4]) ### out of index
print(numbers[3])
# Out:
# 4

# %%
#print"Hello, World!"
print("Hello, World!")
# Out:
# Hello, World!

# %%
#x = 5 / 0 ## zero devision error
x = 5 / 1

# %%
name = "Amrish"
age = 25
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Amrish, Age: 25

# %%
#for i in range(1, 10, -1):
#    print(i)
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#x = 10
#if x = 5:
#    print("x is 5")
x = 10
if x == 5:
    print("x is 5")

# %%
def greet(name)
    print("Hello, " + name)
