# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
institute_name = input("Enter the institute name: ")
# Out:
# Enter the institute name:  HOPE AI

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
school_name = input("Enter your school name: ")
degree_name = input("Enter your degree: ")
# Out:
# Enter your name:  Amrish Babu R
# Enter your age:  29
# Enter your school name:  Little Flower Convent Matric. Hr.Sec School
# Enter your degree:  B.E/ECE

# %%
a, b = 43, 34
print("a= ", a, "\nb= ", b)
print("add= ", a+b)
# Out:
# a=  43
# b=  34
# add=  77

# %%
a, b = 43, 34
print("a= ", a, "\nb= ", b)
print("Sub= ", a-b)
# Out:
# a=  43
# b=  34
# Sub=  9

# %%
a, b = 63, 97
print("a= ", a, "\nb= ", b)
print("Mul = ", a*b)
# Out:
# a=  63
# b=  97
# Mul =  6111

# %%
a, b = 76, 31
print("a= ", a, "\nb=", b)
print("Float Div = ", a / b)
# Out:
# a=  76
# b= 31
# Float Div =  2.4516129032258065

# %%
a, b = 76, 31
print("a= ", a, "\nb=", b)
print("Floor Div = ", a // b)
# Out:
# a=  76
# b= 31
# Floor Div =  2

# %%
a, b = 76, 31
print("a= ", a, "\nb= ",b)
print("Modulo = ", a % b)
# Out:
# a=  76
# b=  31
# Modulo =  14

# %%
a, b = 4, 4
print("a= ", a, "\nb= ",b)
print("Power = ", a ** b)
# Out:
# a=  4
# b=  4
# Power =  256
