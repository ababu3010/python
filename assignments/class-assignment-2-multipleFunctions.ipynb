# %%
from multipleFunctions import multipleFunctions

# %%
multipleFunctions.Subfields()
# Out:
# Sub-fields in AI are:
#
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Processing Language

# %%
multipleFunctions.OddEven()
# Out:
# Enter the number:  52452
# 52452 is Even number

# %%
multipleFunctions.Eligibile()
# Out:
# Your Gender:  Male
# Your age:  18
# 'Not Eligible'

# %%
multipleFunctions.percentage()
# Out:
# Subject1=  98
# Subject2=  87
# Subject3=  96
# Subject4=  96
# Subject5=  96
# 'Total : 473, Percentage: 94.6'

# %%
multipleFunctions.triangle()
# Out:
# Enter the height to calculate Area of triangle:  5
# Enter the breadth_area to calculate Area of triangle:  10
# Enter the height1 to calculate perimeter of triangle:  5
# Enter the height2 to calculate perimeter of triangle:  5
# Enter the breadth to calculate perimeter of triangle:  10
# Area Formula: (Height*Breadth)/2
# Area of Triangle:  25.0
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:  20
