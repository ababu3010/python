# %%
print()

# %%
print("Hello, Welcome to Hope AI")
# Out:
# Hello, Welcome to Hope AI

# %%
print("Lets start learn Python Basics")
# Out:
# Lets start learn Python Basics

# %%
Print("Hi")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Print("Hi")
#
# NameError: name 'Print' is not defined
