# %%
num1 = 10
num2 = 30
sum_of_2nums = num1 + num2

# %%
num1 = 10
num2 = 30
sum_of_2nums = num1 + num2
print("sum_of_2nums")
print(sum_of_2nums)
# Out:
# sum_of_2nums
# 40

# %%
Num1 = 5
Num2 = 100
Add = Num1 + Num2
Sub = Num2 - Num1

# %%
print("Variable name shouldn't have a space in there names")
first name = "Amrish Babu R"
# Out:
#   Cell In[8], line 2
#     first name = "Amrish Babu R"
#           ^
# SyntaxError: invalid syntax

# %%
print("Valid variable names should be as below samples. Variable name should not start with numbers as well.")
first_name = "Amrish Babu R"
firstName = "Amrish Babu R"
FirstName = "Amrish Babu R"
# Out:
# Valid variable names should be as below samples. Variable name should not start with numbers as well.

# %%
print("The addition of two numbers")
num1 = 10
num2 = 20
print("The number1:", num1)
print("The number2:", num2)
add = num1+num2
print("The Addition of two numbers:", add)
# Out:
# The addition of two numbers
# The number1: 10
# The number2: 20
# The Addition of two numbers: 30
